# %%
from image_classification_simulation.data.office31_loader import Office31Loader, Office31LoaderViT
import torch
import numpy as np
import matplotlib.pyplot as plt

# %%
# Playing here with data augmentation probability value (for no data aug. use value 0)
hparams = {
    "loss": "MSELoss",
    "optimizer": "adam",
    "num_channels": 3,
    "num_filters": 16,
    "batch_size": 16,
    "data_aug_prob": 0,
}

office_loader = Office31LoaderViT("/home/mila/a/aldo.zaimi/data/domain_adaptation_images/amazon/images", hyper_params=hparams)
office_loader.setup(stage="fit")
train_dl=office_loader.train_dataloader()
# Out:
# Number of workers set to: 1
# image size set to: 224
# Number of workers set to: 1
# image size set to: 224

# %%
dataiter = iter(train_dl)
images, labels = dataiter.next()
images = images.numpy()

fig = plt.figure(figsize=(8, 8))
for idx in np.arange(9):
    ax = fig.add_subplot(3, 3, idx+1, xticks=[], yticks=[])
    plt.imshow(np.transpose(images[idx], (1, 2, 0)))
